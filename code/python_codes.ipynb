# %%
import pandas as pd

calendar_df = pd.read_csv("./data/calendar.csv.gz")
calendar_df.head(10)
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0        3686  2024-06-21         f  $67.00             NaN              31
# 1        3686  2024-06-22         f  $67.00             NaN              31
# 2        3686  2024-06-23         f  $67.00             NaN              31
# 3        3686  2024-06-24         f  $67.00             NaN              31
# 4        3686  2024-06-25         f  $67.00             NaN              31
# 5        3686  2024-06-26         f  $67.00             NaN              31
# 6        3686  2024-06-27         f  $67.00             NaN              31
# 7        3686  2024-06-28         f  $67.00             NaN              31
# 8        3686  2024-06-29         f  $67.00             NaN              31
# 9        3686  2024-06-30         f  $67.00             NaN              31
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365
# 5             365
# 6             365
# 7             365
# 8             365
# 9             365

# %%
listings_df = pd.read_csv("./data/listings.csv.gz")
listings_df.head(10)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3686   https://www.airbnb.com/rooms/3686  20240621025859   2024-06-21
# 1   3943   https://www.airbnb.com/rooms/3943  20240621025859   2024-06-21
# 2   4197   https://www.airbnb.com/rooms/4197  20240621025859   2024-06-21
# 3   4529   https://www.airbnb.com/rooms/4529  20240621025859   2024-06-21
# 4   5589   https://www.airbnb.com/rooms/5589  20240621025859   2024-06-21
# 5   6165   https://www.airbnb.com/rooms/6165  20240621025859   2024-06-21
# 6   7103   https://www.airbnb.com/rooms/7103  20240621025859   2024-06-21
# 7  11785  https://www.airbnb.com/rooms/11785  20240621025859   2024-06-21
# 8  12442  https://www.airbnb.com/rooms/12442  20240621025859   2024-06-21
# 9  14218  https://www.airbnb.com/rooms/14218  20240621025859   2024-06-21
#
#             source                                               name  \
# 0      city scrape                                    Vita's Hideaway
# 1      city scrape                   Historic Rowhouse Near Monuments
# 2      city scrape                 Capitol Hill Bedroom walk to Metro
# 3      city scrape                          Bertina's  House Part One
# 4  previous scrape                           Cozy apt in Adams Morgan
# 5      city scrape   Private Bath & Laundry  + Huge Lower Level Suite
# 6      city scrape  Lovely guest suite in a quiet but close-in nei...
# 7      city scrape                           Sanctuary near Cathedral
# 8      city scrape                     Peaches & Cream near Cathedral
# 9      city scrape                 Quiet Comfort near Nat'l Cathedral
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  You will be staying in high ceiling  bedroom w...
# 2  This is the middle bedroom upstairs in a resto...
# 3  This is  large private  bedroom with plenty of...
# 4  This is a 1 br (bedroom + living room in Adams...
# 5  DC/Cozy/huge lower level private room/suite  w...
# 6  Private guest suite with cathedral ceiling, su...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                neighborhood_overview  \
# 0  We love that our neighborhood is up and coming...
# 1  This rowhouse is centrally located in the hear...
# 2  Our area, the Eastern Market neighborhood of C...
# 3  Very quiet neighborhood and it is easy accessi...
# 4  Adams Morgan spills over with hipsters, salsa ...
# 5  16th Street Heights. Safe and quiet.  Close to...
# 6                                                NaN
# 7  Our neighborhood is informally known as Cathed...
# 8  There is so much to love in Cathedral Heights!...
# 9                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/61e02c7e-3d66...     4645  ...
# 1  https://a0.muscache.com/pictures/airflow/Hosti...     5059  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     5061  ...
# 3  https://a0.muscache.com/pictures/86072003/6709...     5803  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...     6527  ...
# 5  https://a0.muscache.com/pictures/152511/513406...     5782  ...
# 6  https://a0.muscache.com/pictures/ad9eb007-05e9...    17633  ...
# 7  https://a0.muscache.com/pictures/553101/23b288...    32015  ...
# 8  https://a0.muscache.com/pictures/miso/Hosting-...    32015  ...
# 9  https://a0.muscache.com/pictures/miso/Hosting-...    32015  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.84                   3.91                4.64
# 1                        4.91                   4.59                4.76
# 2                        4.98                   4.97                4.95
# 3                        4.93                   4.51                4.83
# 4                        4.82                   4.91                4.44
# 5                        4.80                   4.53                4.87
# 6                        4.90                   4.79                4.81
# 7                        4.88                   4.84                4.58
# 8                        4.84                   4.82                4.58
# 9                        4.87                   4.89                4.67
#
#                             license instant_bookable  \
# 0                               NaN                f
# 1  Hosted License: 5007242201001033                f
# 2  Hosted License: 5007242201000749                f
# 3                            Exempt                f
# 4                               NaN                f
# 5                               NaN                f
# 6                               NaN                f
# 7                               NaN                f
# 8                               NaN                t
# 9                               NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              5                                           0
# 2                              2                                           0
# 3                              2                                           0
# 4                              1                                           1
# 5                              1                                           0
# 6                             28                                          28
# 7                              4                                           1
# 8                              4                                           1
# 9                              4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            5
# 2                                            2
# 3                                            2
# 4                                            0
# 5                                            1
# 6                                            0
# 7                                            3
# 8                                            3
# 9                                            3
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.51
# 1                                           0              2.74
# 2                                           0              0.33
# 3                                           0              0.56
# 4                                           0              0.53
# 5                                           0              0.13
# 6                                           0              0.52
# 7                                           0              2.35
# 8                                           0              0.68
# 9                                           0              0.65
#
# [10 rows x 75 columns]

# %%
reviews_df = pd.read_csv("./data/reviews.csv.gz")
reviews_df.head(10)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        3686    131293  2010-11-01       257234        Callie
# 1       32087    567384  2011-09-25      1192632          Sven
# 2       32087   1708259  2012-07-14      1321181       Michael
# 3       32087   5389855  2013-06-27      4642537           Yve
# 4       32087  11115970  2014-03-21     12842454       Crystal
# 5      893529   5144488  2013-06-15      2113920         Sunny
# 6        3686    150766  2010-12-08       255888       Patrick
# 7        3686    177749  2011-02-02       366688      Benjamin
# 8        3686    197451  2011-03-12       213492          T.J.
# 9        3686    213212  2011-03-30       428455          Pete
#
#                                             comments
# 0  Staying with Levita and her wonderful family w...
# 1  Very accommodating host, curteous, beautiful l...
# 2  Excellent! Will definitely stay here again. Gr...
# 3  Staying at American Guest House was the best d...
# 4  The guest house was very nice - most comfortab...
# 5  I enjoyed staying at Kristie's. She is a great...
# 6  Vita is a very welcoming, helpful and friendly...
# 7  This was my first time using "airbnb" and it m...
# 8  First, Vita saved my work week by providing me...
# 9  Great host! Very welcoming and organised. I st...
